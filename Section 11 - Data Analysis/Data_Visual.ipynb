# %% [markdown]
# # Index
# - Matplotlib
# - Distribution Plots
# - Categorical Plot
# - Matrix Plot
# - Regression Plots
# - Cufflinks + plotly
# - Capstone project

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
plt.plot(x,y)
