# %% [markdown]
# ## SUPPORT VECTOR CLASSIFIER IMPLEMENTATION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# lets create synthetic datapoints

# %%
from sklearn.datasets import make_classification
x,y= make_classification(n_samples=1000,n_features=2,n_classes=2,n_clusters_per_class=2,n_redundant=0)

# %%
x
# Out:
# array([[-0.31824981,  1.05054063],
#        [-1.31363654, -2.34154158],
#        [-1.00323272,  1.15449348],
#        ...,
#        [-0.6042025 , -0.88873825],
#        [ 0.21765906, -1.18731158],
#        [-1.32056826, -1.04428559]])

# %%
sns.scatterplot(x = pd.DataFrame(x)[0],y = pd.DataFrame(x)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=10)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel= 'linear')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# prediction

y_pred = svc.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97       131
#            1       0.96      0.97      0.96       119
#
#     accuracy                           0.96       250
#    macro avg       0.96      0.96      0.96       250
# weighted avg       0.96      0.96      0.96       250
#
# [[126   5]
#  [  4 115]]

# %%
rbf =SVC(kernel='rbf')

# %%
rbf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred1 = rbf.predict(x_test)

# %%
print(classification_report(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       131
#            1       0.95      0.97      0.96       119
#
#     accuracy                           0.96       250
#    macro avg       0.96      0.96      0.96       250
# weighted avg       0.96      0.96      0.96       250
#
# [[125   6]
#  [  3 116]]

# %% [markdown]
# Because of the rbf kernal
# internally some transformation has happend and the accuracy of the model has been improved

# %%
poly = SVC(kernel='poly')
poly.fit(x_train,y_train)

# prediction
y_pred2 = poly.predict(x_test)
print(classification_report(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       131
#            1       0.96      0.93      0.94       119
#
#     accuracy                           0.95       250
#    macro avg       0.95      0.95      0.95       250
# weighted avg       0.95      0.95      0.95       250
#
# [[126   5]
#  [  8 111]]

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range 

param_grid = {'C':[0.1,1,10,100,1000],
              "gamma": [1,0.1,0.01,0.001,0.0001],
              'kernel' : ['rbf']}

# %%
grid = GridSearchCV(SVC(),param_grid=param_grid,cv=6,refit = True,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 6 folds for each of 25 candidates, totalling 150 fits
# [CV 1/6] END ........C=0.1, gamma=1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ........C=0.1, gamma=1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/6] END ........C=0.1, gamma=1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END ........C=0.1, gamma=1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 5/6] END ........C=0.1, gamma=1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 6/6] END ........C=0.1, gamma=1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 1/6] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 5/6] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 1/6] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 3/6] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 5/6] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.504 total time=   0.0s
# [CV 2/6] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.504 total time=   0.0s
# [CV 3/6] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 4/6] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 5/6] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 6/6] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 1/6] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.504 total time=   0.0s
# [CV 2/6] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.504 total time=   0.0s
# [CV 3/6] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 4/6] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 5/6] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 6/6] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 1/6] END ..........C=1, gamma=1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 2/6] END ..........C=1, gamma=1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/6] END ..........C=1, gamma=1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END ..........C=1, gamma=1, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 5/6] END ..........C=1, gamma=1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 6/6] END ..........C=1, gamma=1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ........C=1, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ........C=1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ........C=1, gamma=0.1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 4/6] END ........C=1, gamma=0.1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 5/6] END ........C=1, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END ........C=1, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END .......C=1, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END .......C=1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END .......C=1, gamma=0.01, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END .......C=1, gamma=0.01, kernel=rbf;, score=0.888 total time=   0.0s
# [CV 5/6] END .......C=1, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END .......C=1, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ......C=1, gamma=0.001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ......C=1, gamma=0.001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 3/6] END ......C=1, gamma=0.001, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END ......C=1, gamma=0.001, kernel=rbf;, score=0.888 total time=   0.0s
# [CV 5/6] END ......C=1, gamma=0.001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END ......C=1, gamma=0.001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.504 total time=   0.0s
# [CV 2/6] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.504 total time=   0.0s
# [CV 3/6] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 4/6] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 5/6] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 6/6] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 1/6] END .........C=10, gamma=1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END .........C=10, gamma=1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END .........C=10, gamma=1, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END .........C=10, gamma=1, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 5/6] END .........C=10, gamma=1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END .........C=10, gamma=1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/6] END .......C=10, gamma=0.1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 2/6] END .......C=10, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/6] END .......C=10, gamma=0.1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END .......C=10, gamma=0.1, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 5/6] END .......C=10, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 6/6] END .......C=10, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ......C=10, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ......C=10, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ......C=10, gamma=0.01, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 4/6] END ......C=10, gamma=0.01, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 5/6] END ......C=10, gamma=0.01, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END ......C=10, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END .....C=10, gamma=0.001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 2/6] END .....C=10, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END .....C=10, gamma=0.001, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END .....C=10, gamma=0.001, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 5/6] END .....C=10, gamma=0.001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END .....C=10, gamma=0.001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 1/6] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 3/6] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 5/6] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ........C=100, gamma=1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 2/6] END ........C=100, gamma=1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ........C=100, gamma=1, kernel=rbf;, score=0.920 total time=   0.0s
# [CV 4/6] END ........C=100, gamma=1, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 5/6] END ........C=100, gamma=1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END ........C=100, gamma=1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 1/6] END ......C=100, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ......C=100, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/6] END ......C=100, gamma=0.1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END ......C=100, gamma=0.1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 5/6] END ......C=100, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END ......C=100, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END .....C=100, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END .....C=100, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END .....C=100, gamma=0.01, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 4/6] END .....C=100, gamma=0.01, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 5/6] END .....C=100, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END .....C=100, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ....C=100, gamma=0.001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ....C=100, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ....C=100, gamma=0.001, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END ....C=100, gamma=0.001, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 5/6] END ....C=100, gamma=0.001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END ....C=100, gamma=0.001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 2/6] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.904 total time=   0.0s
# [CV 5/6] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 1/6] END .......C=1000, gamma=1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 2/6] END .......C=1000, gamma=1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 3/6] END .......C=1000, gamma=1, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END .......C=1000, gamma=1, kernel=rbf;, score=0.904 total time=   0.0s
# [CV 5/6] END .......C=1000, gamma=1, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END .......C=1000, gamma=1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 1/6] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 2/6] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/6] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 5/6] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 6/6] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/6] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 2/6] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.904 total time=   0.0s
# [CV 5/6] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 6/6] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 1/6] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/6] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/6] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.936 total time=   0.0s
# [CV 4/6] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.904 total time=   0.0s
# [CV 5/6] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 1/6] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.960 total time=   0.0s
# [CV 2/6] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 3/6] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 4/6] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 5/6] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.944 total time=   0.0s
# [CV 6/6] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.952 total time=   0.0s
# GridSearchCV(cv=6, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
y_pred4 = grid.predict(x_test)

print(classification_report(y_test,y_pred4))
print(confusion_matrix(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       131
#            1       0.94      0.97      0.96       119
#
#     accuracy                           0.96       250
#    macro avg       0.96      0.96      0.96       250
# weighted avg       0.96      0.96      0.96       250
#
# [[124   7]
#  [  3 116]]
