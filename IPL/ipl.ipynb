# %% [markdown]
# IPL 2022 CAPSTONE PROJECT

# %% [markdown]
# The Indian Premier League(IPL) is a professional T20 cricket league in india, featuring franchises representing cities. the prohect explores IPL 2022 match level data to derive meaningful insights and understand match outcomes, players performance and team dynamics.
