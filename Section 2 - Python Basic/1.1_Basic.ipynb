# %% [markdown]
# - Single line comments and multiple line comments
# - Defination of syntax and semantics
# - Basic Syntax rules in python
# - Understanding semantics in python
# - Common syntax errors and how to avoid them
# - Practical code examples

# %% [markdown]
# Syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structed programs in a language. in simpler terms syntax is about the correct arrangement of words and symbols in a code
#
#
#
# semantics refers to the meaning or the interpretation of the symbols, characters and commandas in a language. it is about what the code is supposed to do when it runs

# %%
# this is comment

# %%
'''
This is the multiline
comments
'''
# Out:
# '\nThis is the multiline\ncomments\n'

# %%
# case sensitivity - python is a case sensitive

name = 'Shivam'
Name = 'Shivam shahi'


print(name)
print(Name)
# Out:
# Shivam
# Shivam shahi

# %%
# Indentation
# Python use indentation to define blocks of code. consistent use of spaces (commonly 4) or a tab is required

age = 32

if age >30:
    print("You are more then 30 years old")
print(age)
# Out:
# You are more then 30 years old
# 32

# %%
# Line continuation 
# use a backslash (\) to continue a statement to the next line

total = 1+2+3+4+5+6+\
7+8+9

print(total)
# Out:
# 45

# %%
# multiple statements on a single line

x= 5;y = 10 ; z = x+y

print(z)
# Out:
# 15

# %%
# Semnatics in python

# variable assignment 

age = 32 #int
name = "shivam" #str

# %%
if True:
    print("this will get printed")
    if False:
        print("this wont print")
    print('Another print statement')
print('Outside print')
# Out:
# this will get printed
# Another print statement
# Outside print
