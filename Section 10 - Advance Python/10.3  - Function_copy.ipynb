# %%
# function copy
def welcome():
   return 'Welcome to the function'

# %%
wel = welcome
print(welcome())

del welcome

print(wel())
# Out:
# Welcome to the function
# Welcome to the function

# %%
# closures

# function inside a function

def main_welcome():
    msg = 'Welcome'
    def sub_welcome():
        print('welcome to the adv. python')
        print(msg)
    return sub_welcome()

# %%
main_welcome()
# Out:
# welcome to the adv. python
# Welcome
