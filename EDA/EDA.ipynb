# %% [markdown]
# About this file
#
# This dataset, titled "Daily Lifestyle and Academic Performance of Students", contains data from 2,000 students collected via a Google Form survey. It includes information on study hours, extracurricular activities, sleep, socializing, physical activity, stress levels, and CGPA. The data covers an academic year from August 2023 to May 2024 and reflects student lifestyles primarily from India. This dataset can help analyze the impact of daily habits on academic performance and student well-being.
#
# File Name: Daily_Lifestyle_and_Academic_Performance.csv
# File Format: CSV
# Number of Records: 2000 rows
# Number of Columns: 8 columns
# Column Names: Student ID, Stud- y Hours, Extracurricular Hours, Sleep Hours, Social Hours, Physical Activity Hours, Stress Level, CGPA

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_lifestyle_dataset.csv')

# %%
df.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# 3  2.88     Moderate
# 4  3.51         High

# %%
df.isnull().sum()
# Out:
# Student_ID                         0
# Study_Hours_Per_Day                0
# Extracurricular_Hours_Per_Day      0
# Sleep_Hours_Per_Day                0
# Social_Hours_Per_Day               0
# Physical_Activity_Hours_Per_Day    0
# GPA                                0
# Stress_Level                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Student_ID                       2000 non-null   int64
#  1   Study_Hours_Per_Day              2000 non-null   float64
#  2   Extracurricular_Hours_Per_Day    2000 non-null   float64
#  3   Sleep_Hours_Per_Day              2000 non-null   float64
#  4   Social_Hours_Per_Day             2000 non-null   float64
#  5   Physical_Activity_Hours_Per_Day  2000 non-null   float64
#  6   GPA                              2000 non-null   float64
#  7   Stress_Level                     2000 non-null   object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 125.1+ KB

# %%
df.Stress_Level.value_counts()
# Out:
# Stress_Level
# High        1029
# Moderate     674
# Low          297
# Name: count, dtype: int64

# %%
df.Stress_Level = df.Stress_Level.map({'Low':0,'Moderate':1,'High':2})

# %%
df.Stress_Level.value_counts()
# Out:
# Stress_Level
# 2    1029
# 1     674
# 0     297
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                                  Student_ID  Study_Hours_Per_Day  \
# Student_ID                         1.000000             0.014034
# Study_Hours_Per_Day                0.014034             1.000000
# Extracurricular_Hours_Per_Day     -0.018424            -0.002629
# Sleep_Hours_Per_Day               -0.001411             0.026717
# Social_Hours_Per_Day              -0.004363            -0.137820
# Physical_Activity_Hours_Per_Day    0.004273            -0.488113
# GPA                                0.005416             0.734468
# Stress_Level                       0.003306             0.738843
#
#                                  Extracurricular_Hours_Per_Day  \
# Student_ID                                           -0.018424
# Study_Hours_Per_Day                                  -0.002629
# Extracurricular_Hours_Per_Day                         1.000000
# Sleep_Hours_Per_Day                                   0.008844
# Social_Hours_Per_Day                                 -0.139081
# Physical_Activity_Hours_Per_Day                      -0.369989
# GPA                                                  -0.032174
# Stress_Level                                         -0.006099
#
#                                  Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# Student_ID                                 -0.001411             -0.004363
# Study_Hours_Per_Day                         0.026717             -0.137820
# Extracurricular_Hours_Per_Day               0.008844             -0.139081
# Sleep_Hours_Per_Day                         1.000000             -0.193556
# Social_Hours_Per_Day                       -0.193556              1.000000
# Physical_Activity_Hours_Per_Day            -0.470302             -0.417142
# GPA                                        -0.004278             -0.085677
# Stress_Level                               -0.298917             -0.054702
#
#                                  Physical_Activity_Hours_Per_Day       GPA  \
# Student_ID                                              0.004273  0.005416
# Study_Hours_Per_Day                                    -0.488113  0.734468
# Extracurricular_Hours_Per_Day                          -0.369989 -0.032174
# Sleep_Hours_Per_Day                                    -0.470302 -0.004278
# Social_Hours_Per_Day                                   -0.417142 -0.085677
# Physical_Activity_Hours_Per_Day                         1.000000 -0.341152
# GPA                                                    -0.341152  1.000000
# Stress_Level                                           -0.205207  0.550395
#
#                                  Stress_Level
# Student_ID                           0.003306
# Study_Hours_Per_Day                  0.738843
# Extracurricular_Hours_Per_Day       -0.006099
# Sleep_Hours_Per_Day                 -0.298917
# Social_Hours_Per_Day                -0.054702
# Physical_Activity_Hours_Per_Day     -0.205207
# GPA                                  0.550395
# Stress_Level                         1.000000

# %%
plt.figure(figsize=(10, 10))
# Compute the correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
sns.heatmap(data=corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title("Heatmap of Feature Correlations")
plt.show()
